# %%
from calc_uavsar_inc import calc_inc_angle
import matplotlib.pyplot as plt

# %%
inc = calc_inc_angle(dem = '/Users/zachkeskinen/Documents/uavsar_snow/incidence_angle/geolocated_dem_lkv/llh.dem.tif',
lkv_x = '/Users/zachkeskinen/Documents/uavsar_snow/incidence_angle/geolocated_dem_lkv/lkv.x.tif',
lkv_y = '/Users/zachkeskinen/Documents/uavsar_snow/incidence_angle/geolocated_dem_lkv/lkv.y.tif',
lkv_z = '/Users/zachkeskinen/Documents/uavsar_snow/incidence_angle/geolocated_dem_lkv/lkv.z.tif')

# %%
plt.imshow(inc, vmin=20, vmax=80)
plt.colorbar()

# %%
inc[1000:1100,1000:1100]
# Out:
# array([[1.3997815081198743, 1.3196290917273592, 1.3181794927182373, ...,
#         1.282352958396481, 1.2773231684393485, 1.2734954556809712],
#        [1.397943605384963, 1.3193050018337737, 1.319767820915898, ...,
#         1.240805423370212, 1.280316357418116, 1.2815379251619499],
#        [1.4051869267605437, 1.4095432034167943, 1.3276314763467512, ...,
#         1.2776422084987131, 1.2818253778811628, 1.2847450941755143],
#        ...,
#        [1.3434338270581523, 1.4403249757448202, 1.4331121984210875, ...,
#         0.7324424486152079, 0.8596194528101426, 0.8816306093291111],
#        [1.3238955600215514, 1.3249441854419923, 1.4101707091320623, ...,
#         0.8497202056133379, 0.8676528245323948, 0.889438821517252],
#        [1.3057528078392169, 1.3210880860417977, 1.3901685599525542, ...,
#         0.8501181110083902, 0.8678664342651882, 0.8931685407009577]],
#       dtype=object)

# %%
import numpy as np
inc[inc == None] = np.nan

# %%
plt.imshow(np.rad2deg(inc.astype(float)))

# %%
plt.imshow(np.rad2deg(inc), vmin = 20, vmax = 80)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'float' object has no attribute 'rad2deg'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /Users/zachkeskinen/Documents/uavsar_snow/incidence_angle/test_func.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/zachkeskinen/Documents/uavsar_snow/incidence_angle/test_func.ipynb#ch0000002?line=0'>1</a> plt.imshow(np.rad2deg(inc), vmin = 20, vmax = 80)
#
# TypeError: loop of ufunc does not support argument 0 of type float which has no callable rad2deg method

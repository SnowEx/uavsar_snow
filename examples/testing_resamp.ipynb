# %%
from dem_resample import resample_to_uavsar_dem

# %%
uavsar = '/Users/jacktarricone/ch1_jemez_data/new_py_inc/lkv.z.tif'
new = '/Users/jacktarricone/ch1_jemez_data/new_py_inc/jemez_fabdem.tif'

# %%
resample = resample_to_uavsar_dem(path_new_dem=new, path_uavsar_dem=uavsar)

# %%
import matplotlib.pyplot as plt
plt.imshow(resample)
